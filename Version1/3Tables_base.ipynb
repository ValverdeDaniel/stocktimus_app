# %%
# %run fundamentalFunctions.ipynb
# %run epsTrendFunctions.ipynb

# %% [markdown]
# # Fundamentals

# %%
raw1 = ['msft', 'aapl', 'goog', 'U']
tickers = [f"{t}.US" for t in raw1]
print(tickers)
dfFundamentals = FundamentalsBuilder(tickers)
display(dfFundamentals)
dfFundamentals.to_csv('Fundamentals.csv', index=False)
# Out:
# ['msft.US', 'aapl.US', 'goog.US', 'U.US']
#   Ticker  Current Price  All-Time High  ATH %Chg  6-Month High  \
# 0   msft         458.17       464.0025 -0.012570      458.8700
# 1   aapl         206.86       258.3967 -0.199448      258.3967
# 2   goog         165.32       207.4736 -0.203176      207.4736
# 3      U          22.23       201.1200 -0.889469       28.3400
#
#    Recent-High %Chg  5-Year High  Current P/E  Avg 5-Year P/E  \
# 0         -0.001525     464.0025    35.462100       37.168119
# 1         -0.199448     258.3967    32.171100       34.264445
# 2         -0.203176     207.4736    18.450900       30.353938
# 3         -0.215596     201.1200   -19.848214      108.239528
#
#    Fair Value (TTM)  Fair Value %Chg  Avg P/E × Fwd EPS  MACD (12,26,9)  \
# 0        480.212094         0.048109         562.119478       18.315549
# 1        220.320380         0.065070         268.061031        0.490787
# 2        271.971288         0.645120         307.652343        1.363543
# 3       -121.228271        -6.453364         -83.474324        0.414941
#
#    MACD Signal  RSI (1 yr)     Live Price Time
# 0    16.623502   77.423106 2025-05-20 16:28:00
# 1    -0.180808   49.859880 2025-05-20 16:28:00
# 2     0.562777   54.158697 2025-05-20 16:28:00
# 3     0.313119   56.544936 2025-05-20 16:28:00

# %% [markdown]
# # epsTrends table

# %%
    test = ['msft', 'aapl', 'goog', 'U']
    raw = [
        "NET", "CRS", "ORLY", "DOCN", "TEM", "VST", "CVS", "TER", "RIVN", "NTGR",
        "SPOT", "UBER", "SNOW", "ACHR", "ASAN", "RKLB", "DPZ", "LYFT", "NEGG", "MSFT",
        "AAPL", "ARM", "AMZN", "META", "NFLX", "NVDA", "GOOG", "RDFN", "MDB", "Z",
        "INTC", "AMD", "AFRM", "COIN", "TSLA", "HOOD", "CAVA", "F", "GM", "SMR", "U",
        "RDDT", "SHOP", "SOFI"
    ]
    tickers = [f"{t}.US" for t in test]
    dfEPS = build_eps_trends(tickers)
    display(dfEPS)
# Out:
# msft.US ...ok
# aapl.US ...ok
# goog.US ...ok
# U.US ...ok
#   Ticker  Curr Qtr Curr  Curr Qtr 7  Curr Qtr 30  Curr Qtr 60  Curr Qtr 90  \
# 0   msft         3.2160      3.2147       3.2134       3.2129       3.1535
# 1   aapl         1.4169      1.4157       1.4646       1.4933       1.4994
# 2   goog         2.1729      2.1727       2.1366       2.1738       2.1758
# 3      U        -0.2877     -0.2761      -0.2973      -0.2973      -0.2917
#
#    Next Qtr Curr  Next Qtr 7  Next Qtr 30  Next Qtr 60  ...  Curr Yr Curr  \
# 0         3.5526      3.5526       3.5397       3.5453  ...       13.3929
# 1            NaN         NaN          NaN          NaN  ...        7.1761
# 2         2.2452      2.2445       2.2340       2.2664  ...        9.5763
# 3        -0.2249     -0.2240      -0.2542      -0.2542  ...       -0.8788
#
#    Curr Yr 7  Curr Yr 30  Curr Yr 60  Curr Yr 90  Next Yr Curr  Next Yr 7  \
# 0    13.4042     13.1428     13.1534     13.1566       15.1237    15.1231
# 1     7.1882      7.2449      7.3162      7.3333        7.8233     7.8497
# 2     9.5762      8.9298      8.9777      8.9873       10.1355    10.1617
# 3    -0.8838     -1.1334     -1.1373     -1.2062       -0.7712    -0.8849
#
#    Next Yr 30  Next Yr 60  Next Yr 90
# 0     15.0130     15.0535     15.0714
# 1      7.9792      8.1804      8.2099
# 2     10.1250     10.2291     10.2391
# 3     -0.9115     -0.9147     -1.0166
#
# [4 rows x 21 columns]

# %%
# <!-- Options Analysis -->
# TODO there may be some overlapping global variables or functions from the other notebooks 
    # that are being used because I couldn't use this at the top of the file
# %run optionsFunctions_eod.ipynb

# %%
param_sets2 = [
    {
        "tickers": ["AAPL", "MSFT", "GOOG", "U"],
        "option_type": "call",
        "days_until_exp": 90,
        "strike_pct": 0.15,
        "days_to_gain": 20,
        "stock_gain_pct": 0.1,
        "label": "Short-Term Conservative"
    },
    {
        "tickers": ["AAPL", "MSFT", "GOOG", "U"],
        "option_type": "call",
        "days_until_exp": 180,
        "strike_pct": 0.35,
        "days_to_gain": 45,
        "stock_gain_pct": 0.20,
        "label": "Long-Term Aggressive"
    }
]

dfOptions = run_multiple_analyses(param_sets2)
display(dfOptions)
dfOptions.to_csv('optionsAnalysis.csv', index=False)
# Out:
# 2025-05-21 08:57:50,218 [INFO] No options data returned for MSFT
#    Ticker  Expiration  Strike  % OTM/ITM  Current Stock  Simulated Stock  \
# 0    AAPL  2025-08-15     230      11.19         206.86           227.55
# 1    AAPL  2025-08-15     235      13.60         206.86           227.55
# 2    AAPL  2025-08-15     240      16.02         206.86           227.55
# 3    AAPL  2025-08-15     245      18.44         206.86           227.55
# 4    MSFT  2025-08-15     505      10.22         458.17           503.99
# 5    MSFT  2025-08-15     510      11.31         458.17           503.99
# 6    MSFT  2025-08-15     515      12.40         458.17           503.99
# 7    MSFT  2025-08-15     520      13.49         458.17           503.99
# 8    MSFT  2025-08-15     525      14.59         458.17           503.99
# 9    MSFT  2025-08-15     530      15.68         458.17           503.99
# 10   MSFT  2025-08-15     535      16.77         458.17           503.99
# 11   MSFT  2025-08-15     540      17.86         458.17           503.99
# 12   MSFT  2025-08-15     545      18.95         458.17           503.99
# 13   MSFT  2025-08-15     550      20.04         458.17           503.99
# 14   GOOG  2025-08-15     185      11.90         165.32           181.85
# 15   GOOG  2025-08-15     190      14.93         165.32           181.85
# 16   GOOG  2025-08-15     195      17.95         165.32           181.85
# 17      U  2025-08-15      25      12.46          22.23            24.45
# 18      U  2025-08-15      26      16.96          22.23            24.45
# 19   AAPL  2025-11-21     270      30.52         206.86           248.23
# 20   AAPL  2025-11-21     275      32.94         206.86           248.23
# 21   AAPL  2025-11-21     280      35.36         206.86           248.23
# 22   AAPL  2025-11-21     285      37.77         206.86           248.23
# 23   AAPL  2025-11-21     290      40.19         206.86           248.23
# 24   GOOG  2025-11-21     215      30.05         165.32           198.38
# 25   GOOG  2025-11-21     220      33.08         165.32           198.38
# 26   GOOG  2025-11-21     225      36.10         165.32           198.38
# 27   GOOG  2025-11-21     230      39.12         165.32           198.38
# 28      U  2025-11-21      29      30.45          22.23            26.68
# 29      U  2025-11-21      30      34.95          22.23            26.68
#
#     Current Premium  Simulated Premium  Days Until Expiration  Days to Gain  \
# 0              3.83              10.12                     85            20
# 1              2.75               7.87                     85            20
# 2              2.04               6.04                     85            20
# 3              1.50               4.60                     85            20
# 4              5.15              19.41                     85            20
# 5              4.30              16.93                     85            20
# 6              3.45              14.68                     85            20
# 7              2.81              12.62                     85            20
# 8              2.32              10.81                     85            20
# 9              1.85               9.20                     85            20
# 10             1.53               7.81                     85            20
# 11             1.30               6.61                     85            20
# 12             1.13               5.57                     85            20
# 13             0.86               4.95                     85            20
# 14             4.00               8.94                     85            20
# 15             3.05               6.97                     85            20
# 16             2.29               5.34                     85            20
# 17             1.84               2.50                     85            20
# 18             1.63               2.11                     85            20
# 19             1.80               9.17                    183            45
# 20             1.42               7.75                    183            45
# 21             1.24               6.59                    183            45
# 22             1.01               5.59                    183            45
# 23             0.80               4.76                    183            45
# 24             2.99              10.14                    183            45
# 25             2.64               8.83                    183            45
# 26             2.07               7.51                    183            45
# 27             1.73               6.38                    183            45
# 28             2.12               3.43                    183            45
# 29             1.94               3.11                    183            45
#
#     Stock Gain %  % Gain  Implied Volatility   Delta   Theta  \
# 0           10.0  164.27               26.95  0.2511 -0.0548
# 1           10.0  186.22               26.68  0.1993 -0.0473
# 2           10.0  196.29               26.57  0.1561 -0.0401
# 3           10.0  206.68               26.60  0.1214 -0.0336
# 4           10.0  276.90               20.85  0.2058 -0.0851
# 5           10.0  293.78               20.80  0.1787 -0.0775
# 6           10.0  325.61               20.76  0.1543 -0.0700
# 7           10.0  349.01               20.68  0.1318 -0.0624
# 8           10.0  365.95               20.66  0.1123 -0.0555
# 9           10.0  397.44               20.64  0.0952 -0.0490
# 10          10.0  410.65               20.66  0.0806 -0.0432
# 11          10.0  408.42               20.70  0.0681 -0.0379
# 12          10.0  392.83               20.75  0.0573 -0.0331
# 13          10.0  475.58               21.27  0.0521 -0.0314
# 14          10.0  123.38               31.48  0.2757 -0.0531
# 15          10.0  128.50               31.69  0.2227 -0.0474
# 16          10.0  133.23               31.81  0.1770 -0.0411
# 17          10.0   35.68               64.29  0.4270 -0.0166
# 18          10.0   29.20               64.40  0.3790 -0.0161
# 19          20.0  409.53               25.73  0.1041 -0.0205
# 20          20.0  445.53               25.74  0.0873 -0.0180
# 21          20.0  431.54               25.91  0.0742 -0.0159
# 22          20.0  453.93               26.08  0.0630 -0.0141
# 23          20.0  495.23               26.30  0.0539 -0.0125
# 24          20.0  239.01               31.19  0.1619 -0.0268
# 25          20.0  234.64               31.74  0.1429 -0.0250
# 26          20.0  262.96               31.84  0.1226 -0.0224
# 27          20.0  269.07               31.98  0.1052 -0.0201
# 28          20.0   61.61               63.38  0.3763 -0.0110
# 29          20.0   60.50               63.75  0.3500 -0.0108
#
#                   Run_Label
# 0   Short-Term Conservative
# 1   Short-Term Conservative
# 2   Short-Term Conservative
# 3   Short-Term Conservative
# 4   Short-Term Conservative
# 5   Short-Term Conservative
# 6   Short-Term Conservative
# 7   Short-Term Conservative
# 8   Short-Term Conservative
# 9   Short-Term Conservative
# 10  Short-Term Conservative
# 11  Short-Term Conservative
# 12  Short-Term Conservative
# 13  Short-Term Conservative
# 14  Short-Term Conservative
# 15  Short-Term Conservative
# 16  Short-Term Conservative
# 17  Short-Term Conservative
# 18  Short-Term Conservative
# 19     Long-Term Aggressive
# 20     Long-Term Aggressive
# 21     Long-Term Aggressive
# 22     Long-Term Aggressive
# 23     Long-Term Aggressive
# 24     Long-Term Aggressive
# 25     Long-Term Aggressive
# 26     Long-Term Aggressive
# 27     Long-Term Aggressive
# 28     Long-Term Aggressive
# 29     Long-Term Aggressive
