# %%
# %run fundamentalFunctions.ipynb
# %run epsTrendFunctions.ipynb
# %run optionsFunctions2_eod.ipynb
# Out:
# {
#     "contract": "AAPL250718C00225000",
#     "underlying_symbol": "AAPL",
#     "exp_date": "2025-07-18",
#     "expiration_type": "monthly",
#     "type": "call",
#     "strike": 225,
#     "exchange": "NASDAQ",
#     "currency": "USD",
#     "open": 1.06,
#     "high": 1.2,
#     "low": 0.69,
#     "last": 0.71,
#     "last_size": 2,
#     "change": -0.3,
#     "pctchange": -29.7,
#     "previous": 1.01,
#     "previous_date": "2025-06-10",
#     "bid": 0.7,
#     "bid_date": "2025-06-11 19:59:59",
#     "bid_size": 145,
#     "ask": 0.72,
#     "ask_date": "2025-06-11 19:59:59",
#     "ask_size": 21,
#     "moneyness": -0.13,
#     "volume": 3351,
#     "volume_change": 432,
#     "volume_pctchange": 14.8,
#     "open_interest": 24555,
#     "open_interest_change": 542,
#     "open_interest_pctchange": 2.26,
#     "volatility": 0.274,
#     "volatility_change": 0.0136,
#     "volatility_pctchange": 5.21,
#     "theoretical": 0.71,
#     "delta": 0.091204,
#     "gamma": 0.009455,
#     "theta": -0.040213,
#     "vega": 0.103786,
#     "rho": 0.01766,
#     "tradetime": "2025-06-11",
#     "vol_oi_ratio": 0.14,
#     "dte": 37,
#     "midpoint": 0.71
# }

# %%
EvansTickers = ['nvda', 'biib', 'isrg', 'bx']

# %%
# Example use Screener Tool/bulk research
param_sets = [

    {
        "tickers": EvansTickers,
        "option_type": "call",
        "days_until_exp": 120,
        "strike_pct": 0.2,
        "days_to_gain": 30,
        "stock_gain_pct": 0.1,
        "allocation": 100,
        "label": "Short-Term Conservative"
    },   

        {
        "tickers": EvansTickers,
        "option_type": "put",
        "days_until_exp": 120,
        "strike_pct": -0.2,
        "days_to_gain": 30,
        "stock_gain_pct": -0.1,
        "allocation": 40,
        "label": "Long-Term Aggressive (Put)"
    }

]

combined_results = run_multiple_analyses(param_sets)
display(combined_results)
combined_results.to_csv("optionsScreenerResearch_evan.csv", index=False)
# Out:
#    Ticker Option Type  Expiration  Strike  % OTM/ITM  Current Stock  \
# 0    nvda        call  2025-09-19     175      20.91         144.74
# 1    nvda        call  2025-09-19     170      17.45         144.74
# 2    nvda        call  2025-10-17     175      20.91         144.74
# 3    nvda        call  2025-10-17     170      17.45         144.74
# 4    biib        call  2025-09-19     160      20.78         132.47
# 5    biib        call  2025-09-19     155      17.00         132.47
# 6    biib        call  2025-10-17     160      20.78         132.47
# 7    biib        call  2025-10-17     155      17.00         132.47
# 8    isrg        call  2025-09-19     620      20.79         513.30
# 9    isrg        call  2025-09-19     600      16.89         513.30
# 10   isrg        call  2025-10-17     615      19.81         513.30
# 11   isrg        call  2025-10-17     620      20.79         513.30
# 12     bx        call  2025-09-19     170      20.79         140.74
# 13     bx        call  2025-09-19     165      17.24         140.74
# 14     bx        call  2025-10-17     170      20.79         140.74
# 15     bx        call  2025-10-17     165      17.24         140.74
# 16   nvda         put  2025-09-19     116      19.86         144.74
# 17   nvda         put  2025-09-19     115      20.55         144.74
# 18   nvda         put  2025-10-17     115      20.55         144.74
# 19   nvda         put  2025-10-17     120      17.09         144.74
# 20   biib         put  2025-09-19     105      20.74         132.47
# 21   biib         put  2025-09-19     110      16.97         132.47
# 22   biib         put  2025-10-17     105      20.74         132.47
# 23   biib         put  2025-10-17     110      16.97         132.47
# 24   isrg         put  2025-09-19     410      20.12         513.30
# 25   isrg         put  2025-09-19     420      18.18         513.30
# 26   isrg         put  2025-10-17     410      20.12         513.30
# 27   isrg         put  2025-10-17     420      18.18         513.30
# 28     bx         put  2025-09-19     115      18.29         140.74
# 29     bx         put  2025-09-19     110      21.84         140.74
# 30     bx         put  2025-10-17     115      18.29         140.74
# 31     bx         put  2025-10-17     110      21.84         140.74
#
#     Simulated Stock  Current Premium  Simulated Premium  \
# 0            159.22             3.30               5.82
# 1            159.22             4.17               7.37
# 2            159.22             4.56               7.92
# 3            159.22             5.60               9.64
# 4            145.72             3.75               4.66
# 5            145.72             4.50               6.03
# 6            145.72             5.31               5.88
# 7            145.72             5.15               7.83
# 8            564.63             7.30              11.47
# 9            564.63            10.20              17.12
# 10           564.63            12.20              18.65
# 11           564.63            11.70              16.96
# 12           154.81             1.76               3.56
# 13           154.81             2.20               4.76
# 14           154.81             2.82               5.00
# 15           154.81             3.20               6.72
# 16           130.27             3.15               4.00
# 17           130.27             2.96               3.73
# 18           130.27             3.80               4.93
# 19           130.27             4.85               6.43
# 20           119.23             1.25               2.38
# 21           119.23             2.80               3.54
# 22           119.23             4.17               4.32
# 23           119.23             4.11               4.95
# 24           461.97             5.68              10.37
# 25           461.97             6.63              12.51
# 26           461.97             8.05              14.32
# 27           461.97             9.00              16.39
# 28           126.67             1.85               3.54
# 29           126.67             1.38               2.45
# 30           126.67             3.03               4.62
# 31           126.67             2.72               3.86
#
#     Days Until Expiration  ...   Theta    Bid    Ask  Last Premium  \
# 0                      98  ... -0.0470   3.30   3.35          3.30
# 1                      98  ... -0.0524   4.15   4.25          4.17
# 2                     126  ... -0.0461   4.55   4.65          4.56
# 3                     126  ... -0.0503   5.55   5.65          5.60
# 4                      98  ... -0.0412   2.75   3.10          3.75
# 5                      98  ... -0.0454   3.50   3.90          4.50
# 6                     126  ... -0.0371   2.90   4.20          5.31
# 7                     126  ... -0.0430   4.60   5.10          5.15
# 8                      98  ... -0.1127   6.60   7.20          7.30
# 9                      98  ... -0.1375   9.90  10.40         10.20
# 10                    126  ... -0.1230  11.10  11.60         12.20
# 11                    126  ... -0.1167   9.80  10.70         11.70
# 12                     98  ... -0.0286   1.38   1.96          1.76
# 13                     98  ... -0.0324   2.11   2.48          2.20
# 14                    126  ... -0.0282   2.34   2.59          2.82
# 15                    126  ... -0.0332   3.30   3.55          3.20
# 16                     98  ... -0.0388   3.05   3.15          3.15
# 17                     98  ... -0.0376   2.91   2.96          2.96
#
#     Simulated Equity ($)                   Run_Label
# 0                 176.25     Short-Term Conservative
# 1                 176.76     Short-Term Conservative
# 2                 173.63     Short-Term Conservative
# 3                 172.07     Short-Term Conservative
# 4                 124.22     Short-Term Conservative
# 5                 134.06     Short-Term Conservative
# 6                 110.72     Short-Term Conservative
# 7                 152.08     Short-Term Conservative
# 8                 157.17     Short-Term Conservative
# 9                 167.84     Short-Term Conservative
# 10                152.86     Short-Term Conservative
# 11                144.94     Short-Term Conservative
# 12                202.18     Short-Term Conservative
# 13                216.41     Short-Term Conservative
# 14                177.18     Short-Term Conservative
# 15                209.94     Short-Term Conservative
# 16                 50.85  Long-Term Aggressive (Put)
# 17                 50.47  Long-Term Aggressive (Put)
# 18                 51.93  Long-Term Aggressive (Put)
# 19                 53.05  Long-Term Aggressive (Put)
# 20                 76.24  Long-Term Aggressive (Put)
# 21                 50.64  Long-Term Aggressive (Put)
# 22                 41.44  Long-Term Aggressive (Put)
# 23                 48.21  Long-Term Aggressive (Put)
# 24                 73.02  Long-Term Aggressive (Put)
# 25                 75.46  Long-Term Aggressive (Put)
# 26                 71.13  Long-Term Aggressive (Put)
# 27                 72.83  Long-Term Aggressive (Put)
# 28                 76.46  Long-Term Aggressive (Put)
# 29                 70.95  Long-Term Aggressive (Put)
# 30                 60.98  Long-Term Aggressive (Put)
# 31                 56.75  Long-Term Aggressive (Put)
#
# [32 rows x 25 columns]

# %%
# bought around march 26, 2025

watchlist = [
    {
        "ticker": "NVDA",
        "option_type": "call",
        "strike": 5,
        "expiration": "2027-01-15",
        "days_to_gain": 365,
        "number_of_contracts": 2,
        "average_cost_per_contract": 107.64
    }

]

watchlist_df = whole_watchlist(watchlist)
display(watchlist_df)
watchlist_df.to_csv("watchlist_output_evan.csv", index=False)
# Out:
#   Ticker Option Type  Strike  Expiration  Implied Volatility  \
# 0   NVDA        call       5  2027-01-15              144.54
# 1   NVDA        call       5  2027-01-15              144.54
# 2   NVDA        call       5  2027-01-15              144.54
# 3   NVDA        call       5  2027-01-15              144.54
#
#    Number of Contracts  Average Cost per Contract  Average Cost ($)  \
# 0                    2                     107.64           21528.0
# 1                    2                     107.64           21528.0
# 2                    2                     107.64           21528.0
# 3                    2                     107.64           21528.0
#
#    Current Premium  Your Equity ($)  Total % Change  Days to Gain Scenario %  \
# 0           139.95          27990.0           30.02           365        ±5%
# 1           139.95          27990.0           30.02           365       ±10%
# 2           139.95          27990.0           30.02           365       ±20%
# 3           139.95          27990.0           30.02           365       ±50%
#
#    Stock Price Up  Stock Price Down  Premium Up  Premium Down  \
# 0          151.98            137.50      147.13        132.66
# 1          159.22            130.27      154.37        125.42
# 2          173.69            115.79      168.84        110.95
# 3          217.11             72.37      212.26         67.56
#
#    % Gain from Current (Up)  % Gain from Current (Down)
# 0                      5.13                       -5.21
# 1                     10.30                      -10.38
# 2                     20.64                      -20.72
# 3                     51.67                      -51.72
