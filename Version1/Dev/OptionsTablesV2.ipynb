# %%
# %run fundamentalFunctions.ipynb
# %run epsTrendFunctions.ipynb
# %run optionsFunctions2_eod.ipynb
# Out:
# {
#     "contract": "AAPL250718C00225000",
#     "underlying_symbol": "AAPL",
#     "exp_date": "2025-07-18",
#     "expiration_type": "monthly",
#     "type": "call",
#     "strike": 225,
#     "exchange": "NASDAQ",
#     "currency": "USD",
#     "open": 1.06,
#     "high": 1.2,
#     "low": 0.69,
#     "last": 0.71,
#     "last_size": 2,
#     "change": -0.3,
#     "pctchange": -29.7,
#     "previous": 1.01,
#     "previous_date": "2025-06-10",
#     "bid": 0.7,
#     "bid_date": "2025-06-11 19:59:59",
#     "bid_size": 145,
#     "ask": 0.72,
#     "ask_date": "2025-06-11 19:59:59",
#     "ask_size": 21,
#     "moneyness": -0.13,
#     "volume": 3351,
#     "volume_change": 432,
#     "volume_pctchange": 14.8,
#     "open_interest": 24555,
#     "open_interest_change": 542,
#     "open_interest_pctchange": 2.26,
#     "volatility": 0.274,
#     "volatility_change": 0.0136,
#     "volatility_pctchange": 5.21,
#     "theoretical": 0.71,
#     "delta": 0.091204,
#     "gamma": 0.009455,
#     "theta": -0.040213,
#     "vega": 0.103786,
#     "rho": 0.01766,
#     "tradetime": "2025-06-11",
#     "vol_oi_ratio": 0.14,
#     "dte": 37,
#     "midpoint": 0.71
# }

# %%
EvansTickers = ['nvda', 'biib', 'isrg', 'bx']

# %%
# Example use Screener Tool/bulk research
param_sets = [
    {
        "tickers": tickers,
        "option_type": "call",
        "days_until_exp": 30,
        "strike_pct": 0.1,
        "days_to_gain": 20,
        "stock_gain_pct": 0.08,
        "allocation": 3300,
        "label": "Short-Term Conservative"
    },
    {
        "tickers": tickers,
        "option_type": "put",
        "days_until_exp": 120,
        "strike_pct": -0.2,
        "days_to_gain": 30,
        "stock_gain_pct": -0.1,
        "allocation": 40,
        "label": "Long-Term Aggressive (Put)"
    }
]

combined_results = run_multiple_analyses(param_sets)
display(combined_results)
combined_results.to_csv("optionsScreenerResearch.csv", index=False)
# Out:
#   Ticker Option Type  Expiration  Strike  % OTM/ITM  Current Stock  \
# 0   AAPL        call  2025-09-19     240      21.04         198.29
# 1   AAPL        call  2025-09-19     235      18.51         198.29
# 2   AAPL        call  2025-10-17     240      21.04         198.29
# 3   AAPL        call  2025-10-17     235      18.51         198.29
# 4   AAPL         put  2025-09-19     160      19.31         198.29
# 5   AAPL         put  2025-09-19     155      21.83         198.29
# 6   AAPL         put  2025-10-17     160      19.31         198.29
# 7   AAPL         put  2025-10-17     155      21.83         198.29
#
#    Simulated Stock  Current Premium  Simulated Premium  Days Until Expiration  \
# 0           218.12             1.64               3.70                     98
# 1           218.12             2.18               4.91                     98
# 2           218.12             2.43               5.38                    126
# 3           218.12             3.12               6.78                    126
# 4           178.46             2.10               3.64                     98
# 5           178.46             1.65               2.73                     98
# 6           178.46             2.77               4.79                    126
# 7           178.46             2.24               3.77                    126
#
#    ...   Theta   Bid   Ask  Last Premium             Bid Date  \
# 0  ... -0.0316  1.64  1.68          1.64  2025-06-11 19:59:59
# 1  ... -0.0372  2.17  2.22          2.18  2025-06-11 19:59:59
# 2  ... -0.0328  2.41  2.45          2.43  2025-06-11 19:59:59
# 3  ... -0.0376  3.05  3.15          3.12  2025-06-11 19:59:59
# 4  ... -0.0329  2.05  2.12          2.10  2025-06-11 19:59:59
# 5  ... -0.0288  1.65  1.69          1.65  2025-06-11 19:59:59
# 6  ... -0.0308  2.72  2.77          2.77  2025-06-11 19:59:59
# 7  ... -0.0276  2.21  2.25          2.24  2025-06-11 19:59:59
#
#               Ask Date  Volume  Allocated ($)  Simulated Equity ($)  \
# 0  2025-06-11 19:59:59    1960            100                225.62
# 1  2025-06-11 19:59:59     368            100                225.16
# 2  2025-06-11 19:59:59     201            100                221.24
# 3  2025-06-11 19:59:59      84            100                217.45
# 4  2025-06-11 19:59:59     177             40                 69.38
# 5  2025-06-11 19:59:59      19             40                 66.28
# 6  2025-06-11 19:59:59      28             40                 69.12
# 7  2025-06-11 19:59:59       5             40                 67.35
#
#                     Run_Label
# 0     Short-Term Conservative
# 1     Short-Term Conservative
# 2     Short-Term Conservative
# 3     Short-Term Conservative
# 4  Long-Term Aggressive (Put)
# 5  Long-Term Aggressive (Put)
# 6  Long-Term Aggressive (Put)
# 7  Long-Term Aggressive (Put)
#
# [8 rows x 25 columns]

# %%
# bought around march 26, 2025

watchlist = [
    {
        "ticker": "MU",
        "option_type": "call",
        "strike": 120.0,
        "expiration": "2025-07-18",
        "days_to_gain": 20,
        "number_of_contracts": 4,
        "average_cost_per_contract": 4.5
    },
            {
        "ticker": "MU",
        "option_type": "put",
        "strike": 100.0,
        "expiration": "2025-07-18",
        "days_to_gain": 20,
        "number_of_contracts": 5,
        "average_cost_per_contract": 1.64
    },
    {
        "ticker": "MU",
        "option_type": "call",
        "strike": 145.0,
        "expiration": "2026-01-16",
        "days_to_gain": 60,
        "number_of_contracts": 3,
        "average_cost_per_contract": 10.65
    },
    {
        "ticker": "MU",
        "option_type": "call",
        "strike": 175.0,
        "expiration": "2027-01-15",
        "days_to_gain": 180,
        "number_of_contracts": 3,
        "average_cost_per_contract": 16.25
    },

]

watchlist_df = whole_watchlist(watchlist)
display(watchlist_df)
watchlist_df.to_csv("watchlist_output.csv", index=False)
# Out:
#    Ticker Option Type  Strike  Expiration  Implied Volatility  \
# 0      MU        call   120.0  2025-07-18               55.95
# 1      MU        call   120.0  2025-07-18               55.95
# 2      MU        call   120.0  2025-07-18               55.95
# 3      MU        call   120.0  2025-07-18               55.95
# 4      MU         put   100.0  2025-07-18               59.40
# 5      MU         put   100.0  2025-07-18               59.40
# 6      MU         put   100.0  2025-07-18               59.40
# 7      MU         put   100.0  2025-07-18               59.40
# 8      MU        call   145.0  2026-01-16               49.41
# 9      MU        call   145.0  2026-01-16               49.41
# 10     MU        call   145.0  2026-01-16               49.41
# 11     MU        call   145.0  2026-01-16               49.41
# 12     MU        call   175.0  2027-01-15               47.46
# 13     MU        call   175.0  2027-01-15               47.46
# 14     MU        call   175.0  2027-01-15               47.46
# 15     MU        call   175.0  2027-01-15               47.46
#
#     Number of Contracts  Average Cost per Contract  Average Cost ($)  \
# 0                     4                       4.50            1800.0
# 1                     4                       4.50            1800.0
# 2                     4                       4.50            1800.0
# 3                     4                       4.50            1800.0
# 4                     5                       1.64             820.0
# 5                     5                       1.64             820.0
# 6                     5                       1.64             820.0
# 7                     5                       1.64             820.0
# 8                     3                      10.65            3195.0
# 9                     3                      10.65            3195.0
# 10                    3                      10.65            3195.0
# 11                    3                      10.65            3195.0
# 12                    3                      16.25            4875.0
# 13                    3                      16.25            4875.0
# 14                    3                      16.25            4875.0
# 15                    3                      16.25            4875.0
#
#     Current Premium  Your Equity ($)  Total % Change  Days to Gain Scenario %  \
# 0              6.17           2468.0           37.11            20        ±5%
# 1              6.17           2468.0           37.11            20       ±10%
# 2              6.17           2468.0           37.11            20       ±20%
# 3              6.17           2468.0           37.11            20       ±50%
# 4              2.26           1130.0           37.80            20        ±5%
# 5              2.26           1130.0           37.80            20       ±10%
# 6              2.26           1130.0           37.80            20       ±20%
# 7              2.26           1130.0           37.80            20       ±50%
# 8              9.29           2787.0          -12.77            60        ±5%
# 9              9.29           2787.0          -12.77            60       ±10%
# 10             9.29           2787.0          -12.77            60       ±20%
# 11             9.29           2787.0          -12.77            60       ±50%
# 12            14.04           4212.0          -13.60           180        ±5%
# 13            14.04           4212.0          -13.60           180       ±10%
# 14            14.04           4212.0          -13.60           180       ±20%
# 15            14.04           4212.0          -13.60           180       ±50%
#
#     Stock Price Up  Stock Price Down  Premium Up  Premium Down  \
# 0           125.83            113.85        8.36          2.15
# 1           131.82            107.86       13.05          0.78
# 2           143.81             95.87       24.14          0.04
# 3           179.76             59.92       59.94          0.00
# 4           125.83            113.85        0.05          0.53
# 5           131.82            107.86        0.01          1.41
# 6           143.81             95.87        0.00          6.32
# 7           179.76             59.92        0.00         39.93
# 8           125.83            113.85       10.12          5.86
# 9           131.82            107.86       12.78          4.25
# 10          143.81             95.87       19.08          1.96
# 11          179.76             59.92       44.57          0.03
# 12          125.83            113.85       12.73          8.63
# 13          131.82            107.86       15.10          6.92
# 14          143.81             95.87       20.50          4.15
# 15          179.76             59.92       41.22          0.35
#
#     % Gain from Current (Up)  % Gain from Current (Down)
# 0                      35.42                      -65.12
# 1                     111.58                      -87.31
# 2                     291.21                      -99.37
# 3                     871.49                     -100.00
# 4                     -97.79                      -76.54
# 5                     -99.43                      -37.73
# 6                     -99.97                      179.69
# 7                    -100.00                     1666.79
# 8                       8.99                      -36.89
# 9                      37.53                      -54.29
# 10                    105.40                      -78.90
# 11                    379.76                      -99.66
# 12                     -9.36                      -38.53
# 13                      7.57                      -50.74
# 14                     45.98                      -70.46
# 15                    193.60                      -97.49
